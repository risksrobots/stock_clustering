# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn
import os
import json
from tqdm.notebook import tqdm

import sklearn

from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.cluster import (KMeans, Birch, SpectralClustering, 
                             MiniBatchKMeans, AgglomerativeClustering)

from sklearn.mixture import GaussianMixture

# %%
with open('config/config.json', 'r') as file:
    config = json.load(file)

# %% [markdown]
# # Loading Data

# %%
df = pd.read_csv(config['ticker_data_preprocessed'], index_col=0)
df_vol = pd.read_csv(config['ticker_data_volume'], index_col=0)
df_index = pd.read_csv(config['ticker_data_sp500'], index_col=0)
df_sectors = pd.read_csv(config['tickers_sectors_path'], index_col=0)
print(df.shape)
df.head()
# Out:
# (484, 853)
#       2018-10-24  2018-10-25  2018-10-26  2018-10-29  2018-10-30  2018-10-31  \
# A      -0.025506    0.024211    0.001917   -0.010362    0.025129    0.018070
# AAL    -0.063002    0.066908    0.002780    0.004313    0.063190    0.012118
# AAP    -0.029213    0.025066    0.008457    0.001945    0.000607   -0.031582
# AAPL   -0.034302    0.021898   -0.015924   -0.018770    0.004994    0.026067
# ABBV   -0.042792    0.029215   -0.011501    0.007055    0.002827   -0.045839
#
#       2018-11-01  2018-11-02  2018-11-05  2018-11-06  ...  2022-03-02  \
# A       0.006637    0.010886   -0.000303    0.001062  ...    0.009323
# AAL     0.036773   -0.001100   -0.016791   -0.015398  ...    0.004911
# AAP     0.023473    0.009113    0.000667    0.018049  ...    0.039270
# AAPL    0.015352   -0.066331   -0.028388    0.010814  ...    0.020588
# ABBV    0.030315   -0.008104    0.037959    0.013078  ...    0.012729
#
#       2022-03-03  2022-03-04  2022-03-07  2022-03-08  2022-03-09  2022-03-10  \
# A       0.030114   -0.023912   -0.026514   -0.007826    0.030467    0.008029
# AAL    -0.040318   -0.071292   -0.119945    0.052181    0.058475   -0.006993
# AAP    -0.003826   -0.007922   -0.025699   -0.003626    0.021438    0.000195
# AAPL   -0.001981   -0.018408   -0.023718   -0.011676    0.034997   -0.027186
# ABBV    0.005616    0.000997   -0.007372   -0.015390    0.011485    0.002217
#
#       2022-03-11  2022-03-14             sector
# A      -0.029926   -0.005218         Healthcare
# AAL    -0.012676    0.021284        Industrials
# AAP    -0.004099   -0.024745  Consumer Cyclical
# AAPL   -0.023909   -0.018742         Technology
# ABBV   -0.000737    0.024420         Healthcare
#
# [5 rows x 853 columns]

# %% [markdown]
# # Preprocessing

# %%
dict_features = dict()
dict_features['original;;'] = df.drop(['sector'], axis=1).values

# %% [markdown]
# ## table data

# %%
table_features = pd.read_csv(config['features_path'], index_col=0)

from sklearn.preprocessing import StandardScaler 
table_features = StandardScaler().fit_transform(table_features)
dict_features['table_data;;'] = table_features

# %% [markdown]
# ## neural network

# %% [markdown]
# # Clustering

# %%
modelname = 'namepreprocessing;surnamepreprocessing;parameterspreproc|clustmodelname;parsmetrsclustering'
parametrs = 'par1name:par1value,par2name:par2value'

example = 'row;originalnowindows;|random;random_state:42'

# %%
def score_func(estimator, X, y):
    labels_predicted = estimator.fit_predict(X)
    score = silhouette_score(X, labels_predicted)
    return score

def gridsearch(model, X, y, parameters:dict):
    custom_cv=[(slice(None), slice(None))]
    grid_search = GridSearchCV(model, param_grid=parameters, scoring=score_func, cv=custom_cv)#, refit=False)
    grid_search.fit(X, y)
    labels_predicted = grid_search.best_estimator_.fit_predict(X)
    return grid_search.best_params_, labels_predicted

def parse_dict(best_params_dict, model_name, preproc_label):
    name = preproc_label + '|' + model_name + ';'
    for key, value in best_params_dict.items():
        name = name + key + ':' + str(value) + ','
    return name[:-1]
    

def train_all(models_dict, params_dict, preproc_label, X, y=None, grid_search=True, n_clusters_=config['n_clusters']):
    output = {}
    for model_name, model in models_dict.items():
        print(model_name)
        param_grid = params_dict[model_name]
        
        if grid_search:
            best_params_dict, labels_predicted = gridsearch(model, X, y, param_grid)
            final_key = parse_dict(best_params_dict, model_name, preproc_label)
        else:
            if model_name == 'Gauss_Mix': 
                model=model(n_components=n_clusters_)
            else:
                model=model(n_clusters=n_clusters_)
                
            model_loc = model.fit(X)
            labels_predicted = model_loc.labels_
            final_key = preproc_label + '|' + 'original'

        
        output[final_key] = labels_predicted
        print('done')
    return output

# %%
models_dict = {'Kmeans': KMeans(),
               'Birch': Birch(),
               'Agglomer': AgglomerativeClustering(),
               'MiniBatchKMeans': MiniBatchKMeans(),
               'Gauss_Mix': GaussianMixture(),
               'Spectral': SpectralClustering()}

n_clusters = np.arange(9, 14)

params_dict = {'Kmeans': 
               {
                   'n_clusters':n_clusters,
                   'init': ['k-means++', 'random'],
                   'algorithm':['auto', 'full', 'elkan']
               },
               'Birch': 
               {
                   #'threshold': np.linspace(0, 1, num=10),
                   'n_clusters': n_clusters,
                   'branching_factor': np.arange(10, 80, step=5)
               },
               'Agglomer': 
               {
                   'n_clusters': n_clusters,
                   'linkage': ['ward', 'complete', 'average', 'single'],
                   #'affinity':['euclidean', 'l1', 'l2', 'manhattan', 'cosine']
               },
               'MiniBatchKMeans':
               {
                   'n_clusters': n_clusters,
                   'init':['k-means++', 'random'],
               },
               'Gauss_Mix': 
               {
                   'n_components': n_clusters,
                   'covariance_type':['full', 'tied', 'diag', 'spherical'],
                   'init_params': ['kmeans', 'random']
               },
               'Spectral': 
               {
                   'n_clusters': n_clusters,
                   'eigen_solver':['arpack', 'lobpcg'],
                   #'affinity': ['nearest_neigbors', 'rbf']
               }
              }

# %%
n_clusters_ = df_sectors['sector'].nunique()

df_predictions = pd.DataFrame(df['sector'].values, index=df.index, columns=['original'])
df_predictions['original_n'] = LabelEncoder().fit_transform(df_predictions['original'])
df_predictions.head()
# Out:
#                original  original_n
# A            Healthcare           6
# AAL         Industrials           7
# AAP   Consumer Cyclical           2
# AAPL         Technology           9
# ABBV         Healthcare           6

# %%
import warnings
warnings.filterwarnings("ignore")

for prepr_name, data in dict_features.items():
    print(f"--------------------- {prepr_name} ---------------------")
    X = data
    y = df['sector'].values
    gridsearch_output = train_all(models_dict, params_dict, preproc_label=prepr_name, X=X, y=y)
    prepr_predictions = pd.DataFrame(gridsearch_output, index=df_predictions.index)
    
    df_predictions = pd.concat([df_predictions, prepr_predictions], axis=1)
    print()
# Out:
# --------------------- original;; ---------------------
# Kmeans
# done
# Birch
# done
# Agglomer
# done
# MiniBatchKMeans
# done
# Gauss_Mix
# done
# Spectral
# done
#
# --------------------- table_data;; ---------------------
# Kmeans
# done
# Birch
# done
# Agglomer
# done
# MiniBatchKMeans
# done
# Gauss_Mix
# done
# Spectral
# done

# %%
df_predictions.head()
# Out:
#                original  original_n  \
# A            Healthcare           6
# AAL         Industrials           7
# AAP   Consumer Cyclical           2
# AAPL         Technology           9
# ABBV         Healthcare           6
#
#       original;;|Kmeans;algorithm:auto,init:k-means++,n_clusters:9  \
# A                                                     8
# AAL                                                   2
# AAP                                                   1
# AAPL                                                  8
# ABBV                                                  0
#
#       original;;|Birch;branching_factor:10,n_clusters:9  \
# A                                                     3
# AAL                                                   0
# AAP                                                   3
# AAPL                                                  3
# ABBV                                                  3
#
#       original;;|Agglomer;linkage:ward,n_clusters:9  \
# A                                                 6
# AAL                                               1
# AAP                                               2
# AAPL                                              6
# ABBV                                              2
#
#       original;;|MiniBatchKMeans;init:k-means++,n_clusters:9  \
# A                                                     1
# AAL                                                   5
# AAP                                                   4
# AAPL                                                  1
# ABBV                                                  3
#
#       original;;|Gauss_Mix;covariance_type:full,init_params:kmeans,n_components:9  \
# A                                                     0
# AAL                                                   7
# AAP                                                   3
# AAPL                                                  2
# ABBV                                                  0
#
#       original;;|Spectral;eigen_solver:arpack,n_clusters:9  \
# A                                                     2
# AAL                                                   6
# AAP                                                   3
# AAPL                                                  2
# ABBV                                                  1
#
#       table_data;;|Kmeans;algorithm:auto,init:k-means++,n_clusters:9  \
# A                                                     0
# AAL                                                   3
# AAP                                                   2
# AAPL                                                  0
# ABBV                                                  1
#
#       table_data;;|Birch;branching_factor:10,n_clusters:9  \
# A                                                     6
# AAL                                                   0
# AAP                                                   2
# AAPL                                                  6
# ABBV                                                  2
#
#       table_data;;|Agglomer;linkage:ward,n_clusters:9  \
# A                                                   6
# AAL                                                 4
# AAP                                                 2
# AAPL                                                6
# ABBV                                                2
#
#       table_data;;|MiniBatchKMeans;init:k-means++,n_clusters:9  \
# A                                                     8
# AAL                                                   2
# AAP                                                   7
# AAPL                                                  8
# ABBV                                                  7
#
#       table_data;;|Gauss_Mix;covariance_type:full,init_params:kmeans,n_components:9  \
# A                                                     6
# AAL                                                   5
# AAP                                                   2
# AAPL                                                  6
# ABBV                                                  2
#
#       table_data;;|Spectral;eigen_solver:arpack,n_clusters:9
# A                                                     2
# AAL                                                   2
# AAP                                                   2
# AAPL                                                  2
# ABBV                                                  2

# %%
df_predictions['original;;|original;'] = df_predictions['original_n']

# %%
model_name = 'original;;|random;random_state:42'

X = df.drop(['sector'], axis=1).values

np.random.seed(42)
clust_pred = np.random.choice(df_predictions['original;;|original;'].unique(), size=len(df))
df_predictions[model_name] = clust_pred

# %%
df_predictions.isna().sum()
# Out:
# original                                                                         0
# original_n                                                                       0
# original;;|Kmeans;algorithm:auto,init:k-means++,n_clusters:9                     0
# original;;|Birch;branching_factor:10,n_clusters:9                                0
# original;;|Agglomer;linkage:ward,n_clusters:9                                    0
# original;;|MiniBatchKMeans;init:k-means++,n_clusters:9                           0
# original;;|Gauss_Mix;covariance_type:full,init_params:kmeans,n_components:9      0
# original;;|Spectral;eigen_solver:arpack,n_clusters:9                             0
# table_data;;|Kmeans;algorithm:auto,init:k-means++,n_clusters:9                   0
# table_data;;|Birch;branching_factor:10,n_clusters:9                              0
# table_data;;|Agglomer;linkage:ward,n_clusters:9                                  0
# table_data;;|MiniBatchKMeans;init:k-means++,n_clusters:9                         0
# table_data;;|Gauss_Mix;covariance_type:full,init_params:kmeans,n_components:9    0
# table_data;;|Spectral;eigen_solver:arpack,n_clusters:9                           0
# original;;|original;                                                             0
# original;;|random;random_state:42                                                0
# dtype: int64

# %% [markdown]
# # Calculating metrics

# %%
from sklearn.metrics import (davies_bouldin_score, 
                            silhouette_score,
                            calinski_harabasz_score,
                            homogeneity_score)

metrics = {'silhouette':silhouette_score, 
           'davies_bouldin':davies_bouldin_score, 
           'calinski_harabasz':calinski_harabasz_score, 
           'homogeneity':homogeneity_score}


metrics_df = pd.DataFrame(columns = list(metrics.keys()))



for features_model in df_predictions.columns[2:]:
    metrics_list = []
    for metric_name, metric_formula in metrics.items():
        if metric_name == 'homogeneity':
            metric_meaning = metric_formula(df_predictions['original'], df_predictions[features_model])
        else:
            features = features_model.split('|')[0]
#             print(features)
#             print(dict_features[features])
            metric_meaning = metric_formula(dict_features[features], df_predictions[features_model])
        metrics_list.append(metric_meaning)
    metrics_df.loc[features_model] = metrics_list
    
metrics_df
# Out:
#                                                     silhouette  \
# original;;|Kmeans;algorithm:auto,init:k-means++...    0.048207
# original;;|Birch;branching_factor:10,n_clusters:9     0.146644
# original;;|Agglomer;linkage:ward,n_clusters:9         0.019951
# original;;|MiniBatchKMeans;init:k-means++,n_clu...    0.025069
# original;;|Gauss_Mix;covariance_type:full,init_...    0.052167
# original;;|Spectral;eigen_solver:arpack,n_clust...    0.030036
# table_data;;|Kmeans;algorithm:auto,init:k-means...    0.188493
# table_data;;|Birch;branching_factor:10,n_cluste...    0.178363
# table_data;;|Agglomer;linkage:ward,n_clusters:9       0.166914
# table_data;;|MiniBatchKMeans;init:k-means++,n_c...    0.139836
# table_data;;|Gauss_Mix;covariance_type:full,ini...    0.146961
# table_data;;|Spectral;eigen_solver:arpack,n_clu...    0.716485
# original;;|original;                                 -0.022305
# original;;|random;random_state:42                    -0.044885
#
#                                                     davies_bouldin  \
# original;;|Kmeans;algorithm:auto,init:k-means++...        2.471094
# original;;|Birch;branching_factor:10,n_clusters:9         1.259800
# original;;|Agglomer;linkage:ward,n_clusters:9             2.800897
# original;;|MiniBatchKMeans;init:k-means++,n_clu...        2.679927
# original;;|Gauss_Mix;covariance_type:full,init_...        2.266082
# original;;|Spectral;eigen_solver:arpack,n_clust...        2.895804
# table_data;;|Kmeans;algorithm:auto,init:k-means...        1.103900
# table_data;;|Birch;branching_factor:10,n_cluste...        1.131710
# table_data;;|Agglomer;linkage:ward,n_clusters:9           1.084454
# table_data;;|MiniBatchKMeans;init:k-means++,n_c...        1.509896
# table_data;;|Gauss_Mix;covariance_type:full,ini...        1.379775
# table_data;;|Spectral;eigen_solver:arpack,n_clu...        0.202122
# original;;|original;                                      3.814749
# original;;|random;random_state:42                        10.173476
#
#                                                     calinski_harabasz  \
# original;;|Kmeans;algorithm:auto,init:k-means++...          21.939596
# original;;|Birch;branching_factor:10,n_clusters:9           14.389994
# original;;|Agglomer;linkage:ward,n_clusters:9               21.653600
# original;;|MiniBatchKMeans;init:k-means++,n_clu...          19.433529
# original;;|Gauss_Mix;covariance_type:full,init_...          20.604249
# original;;|Spectral;eigen_solver:arpack,n_clust...          20.682252
# table_data;;|Kmeans;algorithm:auto,init:k-means...         118.870339
# table_data;;|Birch;branching_factor:10,n_cluste...         103.317828
# table_data;;|Agglomer;linkage:ward,n_clusters:9            104.143630
# table_data;;|MiniBatchKMeans;init:k-means++,n_c...          98.003041
# table_data;;|Gauss_Mix;covariance_type:full,ini...          96.442588
# table_data;;|Spectral;eigen_solver:arpack,n_clu...          19.131619
# original;;|original;                                        10.544538
# original;;|random;random_state:42                            1.009894
#
#                                                     homogeneity
# original;;|Kmeans;algorithm:auto,init:k-means++...     0.231750
# original;;|Birch;branching_factor:10,n_clusters:9      0.088943
# original;;|Agglomer;linkage:ward,n_clusters:9          0.331075
# original;;|MiniBatchKMeans;init:k-means++,n_clu...     0.268930
# original;;|Gauss_Mix;covariance_type:full,init_...     0.225144
# original;;|Spectral;eigen_solver:arpack,n_clust...     0.373567
# table_data;;|Kmeans;algorithm:auto,init:k-means...     0.139976
# table_data;;|Birch;branching_factor:10,n_cluste...     0.121801
# table_data;;|Agglomer;linkage:ward,n_clusters:9        0.116102
# table_data;;|MiniBatchKMeans;init:k-means++,n_c...     0.128757
# table_data;;|Gauss_Mix;covariance_type:full,ini...     0.127635
# table_data;;|Spectral;eigen_solver:arpack,n_clu...     0.001778
# original;;|original;                                   1.000000
# original;;|random;random_state:42                      0.046253

# %%
def rank_methods(df):
    
    for c in df.columns[2:]:
        if c == 'davies_bouldin':
            df[c] = df[c].rank(method='dense',ascending=True).astype(int)
        else:
            df[c] = df[c].rank(method='dense',ascending=False).astype(int)
            
    return df.mean(axis=1)

def choose_method(df_mean_ranked):
    method = df_mean_ranked.argmin()
    return method

df_mean_ranked = rank_methods(metrics_df.copy()) 
metrics_df['mean_ranks'] = df_mean_ranked
method = choose_method(df_mean_ranked)
print('best_method: '+ df_mean_ranked.index[method])

metrics_df = metrics_df.sort_values(by=['mean_ranks'])
metrics_df
# Out:
# best_method: original;;|Agglomer;linkage:ward,n_clusters:9
#                                                     silhouette  \
# original;;|Agglomer;linkage:ward,n_clusters:9         0.019951
# table_data;;|Kmeans;algorithm:auto,init:k-means...    0.188493
# original;;|Spectral;eigen_solver:arpack,n_clust...    0.030036
# original;;|Kmeans;algorithm:auto,init:k-means++...    0.048207
# table_data;;|MiniBatchKMeans;init:k-means++,n_c...    0.139836
# table_data;;|Agglomer;linkage:ward,n_clusters:9       0.166914
# table_data;;|Gauss_Mix;covariance_type:full,ini...    0.146961
# original;;|MiniBatchKMeans;init:k-means++,n_clu...    0.025069
# table_data;;|Birch;branching_factor:10,n_cluste...    0.178363
# original;;|Birch;branching_factor:10,n_clusters:9     0.146644
# table_data;;|Spectral;eigen_solver:arpack,n_clu...    0.716485
# original;;|Gauss_Mix;covariance_type:full,init_...    0.052167
# original;;|original;                                 -0.022305
# original;;|random;random_state:42                    -0.044885
#
#                                                     davies_bouldin  \
# original;;|Agglomer;linkage:ward,n_clusters:9             2.800897
# table_data;;|Kmeans;algorithm:auto,init:k-means...        1.103900
# original;;|Spectral;eigen_solver:arpack,n_clust...        2.895804
# original;;|Kmeans;algorithm:auto,init:k-means++...        2.471094
# table_data;;|MiniBatchKMeans;init:k-means++,n_c...        1.509896
# table_data;;|Agglomer;linkage:ward,n_clusters:9           1.084454
# table_data;;|Gauss_Mix;covariance_type:full,ini...        1.379775
# original;;|MiniBatchKMeans;init:k-means++,n_clu...        2.679927
# table_data;;|Birch;branching_factor:10,n_cluste...        1.131710
# original;;|Birch;branching_factor:10,n_clusters:9         1.259800
# table_data;;|Spectral;eigen_solver:arpack,n_clu...        0.202122
# original;;|Gauss_Mix;covariance_type:full,init_...        2.266082
# original;;|original;                                      3.814749
# original;;|random;random_state:42                        10.173476
#
#                                                     calinski_harabasz  \
# original;;|Agglomer;linkage:ward,n_clusters:9               21.653600
# table_data;;|Kmeans;algorithm:auto,init:k-means...         118.870339
# original;;|Spectral;eigen_solver:arpack,n_clust...          20.682252
# original;;|Kmeans;algorithm:auto,init:k-means++...          21.939596
# table_data;;|MiniBatchKMeans;init:k-means++,n_c...          98.003041
# table_data;;|Agglomer;linkage:ward,n_clusters:9            104.143630
# table_data;;|Gauss_Mix;covariance_type:full,ini...          96.442588
# original;;|MiniBatchKMeans;init:k-means++,n_clu...          19.433529
# table_data;;|Birch;branching_factor:10,n_cluste...         103.317828
# original;;|Birch;branching_factor:10,n_clusters:9           14.389994
# table_data;;|Spectral;eigen_solver:arpack,n_clu...          19.131619
# original;;|Gauss_Mix;covariance_type:full,init_...          20.604249
# original;;|original;                                        10.544538
# original;;|random;random_state:42                            1.009894
#
#                                                     homogeneity  mean_ranks
# original;;|Agglomer;linkage:ward,n_clusters:9          0.331075    3.364170
# table_data;;|Kmeans;algorithm:auto,init:k-means...     0.139976    3.458479
# original;;|Spectral;eigen_solver:arpack,n_clust...     0.373567    3.585168
# original;;|Kmeans;algorithm:auto,init:k-means++...     0.231750    3.903860
# table_data;;|MiniBatchKMeans;init:k-means++,n_c...     0.128757    4.129946
# table_data;;|Agglomer;linkage:ward,n_clusters:9        0.116102    4.650274
# table_data;;|Gauss_Mix;covariance_type:full,ini...     0.127635    5.305347
# original;;|MiniBatchKMeans;init:k-means++,n_clu...     0.268930    5.340999
# table_data;;|Birch;branching_factor:10,n_cluste...     0.121801    5.462015
# original;;|Birch;branching_factor:10,n_clusters:9      0.088943    5.481289
# table_data;;|Spectral;eigen_solver:arpack,n_clu...     0.001778    5.783721
# original;;|Gauss_Mix;covariance_type:full,init_...     0.225144    5.863650
# original;;|original;                                   1.000000    6.358489
# original;;|random;random_state:42                      0.046253    7.625718

# %% [markdown]
# # Saving results

# %%
metrics_df.to_csv(config['metrics_path'])
df_predictions.to_csv(config['predictions_path'])
